# %% [markdown]
# Perform experimental analysis to test the hypotesis that Python's sorted method runs in O(nlog) time on average.

# %%
import time
import random
import matplotlib.pyplot as plt
import math

def run():
    ns=[100, 1000, 5000, 10000, 20000, 50000, 100000, 200000, 500000, 1000000]
    times = []
    for n in ns:
      arr = [random.randint(1, 10*n) for _ in range(n)]
      start = time.time()
      sorted(arr)
      end = time.time()
      times.append(end - start)
      print(f"n={n}, time = {times[-1]:.6f} seconds")
    return ns, times

ns, times = run()
plt.figure(figsize=(10, 6))
plt.plot(ns, times, label='Actual Runtime')
plt.plot(ns, [t/(n*math.log(n)) for t, n in zip(times, ns)], label='Normalized by n log n', linestyle='--')
plt.xlabel('Input Size (n)')
plt.ylabel('Time (seconds)')
plt.title("Sorting Time Complexity (Python's sorted() method)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# n=100, time = 0.000016 seconds
# n=1000, time = 0.000159 seconds
# n=5000, time = 0.000790 seconds
# n=10000, time = 0.001656 seconds
# n=20000, time = 0.003763 seconds
# n=50000, time = 0.011829 seconds
# n=100000, time = 0.024496 seconds
# n=200000, time = 0.061851 seconds
# n=500000, time = 0.243324 seconds
# n=1000000, time = 0.566941 seconds
